# %%
import pandas as pd

filename = 'jensen_comments.csv'
df = pd.read_csv(filename)
df.head()
# Out:
#                                               gen_id          username  \
# 0  7fadff0cb1c60a16b262bf21b6b7e8bbcdfb73cb1c0706...              bart
# 1  0b4f25bab3fa41470e586b2e3d017fe208ca29d5fce609...               Jet
# 2  3e16f39da717b9bbc8acb40d28f93356986157a9b35569...    Petruss.Aureus
# 3  2040b1137f54076443f06629e9d5e4ba2ad5dde012bb4c...             Elise
# 4  47a3c8ea3f22e7927edf0596e95f32f759e6c31951ee00...  Antonio Collenzo
#
#                                                 body  points children parents  \
# 0  WE ZIJN ER BIJNA, WE ZIJN ER BIJNA, MAAR NOG N...       0      NaN     NaN
# 1  Over medisch manipulatie gesproken , deze kan ...       0      NaN     NaN
# 2  Ohh ja Robert, tijd, geschiedenis, hoort tot e...       0      NaN     NaN
# 3  Waarom mensen het niet zien? Antwoordt van mij...       0      NaN     NaN
# 4  Jezus en zijn apostelen zijn nog steeds in de ...       0      NaN     NaN
#
#                   date       date_retrieved  \
# ...

# %%
df = df.loc[:, ~df.columns.str.contains('^Unnamed')]
df.head()
# Out:
#                                               gen_id          username  \
# 0  7fadff0cb1c60a16b262bf21b6b7e8bbcdfb73cb1c0706...              bart
# 1  0b4f25bab3fa41470e586b2e3d017fe208ca29d5fce609...               Jet
# 2  3e16f39da717b9bbc8acb40d28f93356986157a9b35569...    Petruss.Aureus
# 3  2040b1137f54076443f06629e9d5e4ba2ad5dde012bb4c...             Elise
# 4  47a3c8ea3f22e7927edf0596e95f32f759e6c31951ee00...  Antonio Collenzo
#
#                                                 body  points children parents  \
# 0  WE ZIJN ER BIJNA, WE ZIJN ER BIJNA, MAAR NOG N...       0      NaN     NaN
# 1  Over medisch manipulatie gesproken , deze kan ...       0      NaN     NaN
# 2  Ohh ja Robert, tijd, geschiedenis, hoort tot e...       0      NaN     NaN
# 3  Waarom mensen het niet zien? Antwoordt van mij...       0      NaN     NaN
# 4  Jezus en zijn apostelen zijn nog steeds in de ...       0      NaN     NaN
#
#                   date       date_retrieved  \
# ...

# %%
df.to_csv('jensen_comments.csv', index= False)

# %%
from datetime import datetime, timedelta

def convert_cmt_date(strdate, add_hour = True):
    exsplit = ex.split()
    spltime = ' '.join(exsplit[1:-5])
    format_time = datetime.strptime(spltime, '%b %d %Y %H:%M:%S')
    if add_hour:
        time_change = timedelta(hours=1)
        return format_time + time_change
    else:
        return format_time

def convert_ret_date(strdate, add_hour = False):
    exsplit = ex.split()
    newtime = ' '.join(exsplit[1:-5])
    format_time = datetime.strptime(newtime, '%Y %m %d %H:%M:%S')
    if add_hour:
        time_change = timedelta(hours=1)
        return format_time + time_change
    else:
        return format_time

# %%
ex = cmt_time_list[4]
convert_cmt_date(ex)
# Out:
# Jun 18 2021 21:39:28
# datetime.datetime(2021, 6, 18, 22, 39, 28)

# %%
print(cmt_time_list[:5])
# Out:
# ['Fri Jun 18 2021 21:48:08 GMT+0200 (Central European Summer Time)', 'Fri Jun 18 2021 21:43:16 GMT+0200 (Central European Summer Time)', 'Fri Jun 18 2021 21:42:08 GMT+0200 (Central European Summer Time)', 'Fri Jun 18 2021 21:40:02 GMT+0200 (Central European Summer Time)', 'Fri Jun 18 2021 21:39:28 GMT+0200 (Central European Summer Time)']

# %%
cmt_time_list = df.date.to_list()
newtime = []
for cmt in cmt_time_list:
    exsplit = cmt.split()
    spltime = ' '.join(exsplit[1:-5])
    format_time = datetime.strptime(spltime, '%b %d %Y %H:%M:%S')
    time_change = timedelta(hours=1)
    newtime.append(format_time + time_change)
print(newtime[:5])
# Out:
# [datetime.datetime(2021, 6, 18, 22, 48, 8), datetime.datetime(2021, 6, 18, 22, 43, 16), datetime.datetime(2021, 6, 18, 22, 42, 8), datetime.datetime(2021, 6, 18, 22, 40, 2), datetime.datetime(2021, 6, 18, 22, 39, 28)]

# %%
df['date'] = newtime

# %%
df.head()
# Out:
#    Unnamed: 0  Unnamed: 0.1  \
# 0           0             0
# 1           1             1
# 2           2             2
# 3           3             3
# 4           4             4
#
#                                               gen_id          username  \
# 0  7fadff0cb1c60a16b262bf21b6b7e8bbcdfb73cb1c0706...              bart
# 1  0b4f25bab3fa41470e586b2e3d017fe208ca29d5fce609...               Jet
# 2  3e16f39da717b9bbc8acb40d28f93356986157a9b35569...    Petruss.Aureus
# 3  2040b1137f54076443f06629e9d5e4ba2ad5dde012bb4c...             Elise
# 4  47a3c8ea3f22e7927edf0596e95f32f759e6c31951ee00...  Antonio Collenzo
#
#                                                 body  points children parents  \
# 0  WE ZIJN ER BIJNA, WE ZIJN ER BIJNA, MAAR NOG N...       0      NaN     NaN
# 1  Over medisch manipulatie gesproken , deze kan ...       0      NaN     NaN
# 2  Ohh ja Robert, tijd, geschiedenis, hoort tot e...       0      NaN     NaN
# ...

# %%
df.tail()
# Out:
#       Unnamed: 0  Unnamed: 0.1  \
# 7557        7557          7557
# 7558        7558          7558
# 7559        7559          7559
# 7560        7560          7560
# 7561        7561          7561
#
#                                                  gen_id   username  \
# 7557  1e041638e48a5503947c5896e39a02f6e2653a0bcf0282...      Chris
# 7558  77a89672b899c447e1828b9c02a9a4d9ddebe743ab7773...  Anonymous
# 7559  8b1e7c18376dc2e1720f9333260f097a5abf0485a77098...  Anonymous
# 7560  a53abd3788aec3431a4b1f7fb5008d38077c09f5ba4c9e...     Cindy.
# 7561  cae0aec0ad748a4b02424e78afcfea910a01331bef82c2...  Anonymous
#
#                                                    body  points children  \
# 7557  Nou ik ken jammergenoeg juist bijna niemand di...       1      NaN
# 7558  Nog een voorspelling van Jensen Baba die is ui...       1      NaN
# 7559                                                 ❤️       0      NaN
# 7560  Als 1mondmasker niet werkt, draag je er gewoon...       0      NaN
# ...

# %%
ret_time_list = df.date_retrieved.to_list()
newformat_time = [ex.split('.')[0] for ex in ret_time_list]
print(newformat_time[-5:])
# Out:
# ['2021-06-18 22:19:24', '2021-06-18 22:19:24', '2021-06-18 22:19:24', '2021-06-18 22:20:58', '2021-06-18 22:22:46']

# %%
indatetime = [datetime.strptime(tryout, '%Y-%m-%d %H:%M:%S') for tryout in newformat_time]
print(indatetime[-5:])
# Out:
# [datetime.datetime(2021, 6, 18, 22, 19, 24), datetime.datetime(2021, 6, 18, 22, 19, 24), datetime.datetime(2021, 6, 18, 22, 19, 24), datetime.datetime(2021, 6, 18, 22, 20, 58), datetime.datetime(2021, 6, 18, 22, 22, 46)]

# %%
df['date_retrieved'] = indatetime
df.tail()
# Out:
#       Unnamed: 0  Unnamed: 0.1  \
# 7557        7557          7557
# 7558        7558          7558
# 7559        7559          7559
# 7560        7560          7560
# 7561        7561          7561
#
#                                                  gen_id   username  \
# 7557  1e041638e48a5503947c5896e39a02f6e2653a0bcf0282...      Chris
# 7558  77a89672b899c447e1828b9c02a9a4d9ddebe743ab7773...  Anonymous
# 7559  8b1e7c18376dc2e1720f9333260f097a5abf0485a77098...  Anonymous
# 7560  a53abd3788aec3431a4b1f7fb5008d38077c09f5ba4c9e...     Cindy.
# 7561  cae0aec0ad748a4b02424e78afcfea910a01331bef82c2...  Anonymous
#
#                                                    body  points children  \
# 7557  Nou ik ken jammergenoeg juist bijna niemand di...       1      NaN
# 7558  Nog een voorspelling van Jensen Baba die is ui...       1      NaN
# 7559                                                 ❤️       0      NaN
# 7560  Als 1mondmasker niet werkt, draag je er gewoon...       0      NaN
# ...

# %%
cmt_time_list = df.video_upload_time.to_list()
for ex in cmt_time_list[15:20]:
    print(ex)
    print(ex.split('.')[0].replace('T', ' '))
# Out:
# 2021-06-18T13:35:51.834+02:00
# 2021-06-18 13:35:51
# 2021-06-18T13:35:51.834+02:00
# 2021-06-18 13:35:51
# 2021-06-18T13:35:51.834+02:00
# 2021-06-18 13:35:51
# 2021-06-18T13:35:51.834+02:00
# 2021-06-18 13:35:51
# 2021-06-18T13:35:51.834+02:00
# 2021-06-18 13:35:51

# %%
type(df.date_retrieved.to_list()[0])
# Out:
# pandas._libs.tslibs.timestamps.Timestamp

# %%
vid_time = df.video_upload_time.to_list()
small_s = [ex.split('.')[0].replace('T', ' ') for ex in vid_time]
print(small_s[:5])
indat = [datetime.strptime(tryout, '%Y-%m-%d %H:%M:%S') for tryout in small_s]
time_change = timedelta(hours=1)
plusthour = [t+time_change for t in indat]
print(plusthour[:5])
# Out:
# ['2021-06-18 13:35:51', '2021-06-18 13:35:51', '2021-06-18 13:35:51', '2021-06-18 13:35:51', '2021-06-18 13:35:51']
# [datetime.datetime(2021, 6, 18, 14, 35, 51), datetime.datetime(2021, 6, 18, 14, 35, 51), datetime.datetime(2021, 6, 18, 14, 35, 51), datetime.datetime(2021, 6, 18, 14, 35, 51), datetime.datetime(2021, 6, 18, 14, 35, 51)]

# %%
indat[:5]
# Out:
# [datetime.datetime(2021, 6, 18, 13, 35, 51),
#  datetime.datetime(2021, 6, 18, 13, 35, 51),
#  datetime.datetime(2021, 6, 18, 13, 35, 51),
#  datetime.datetime(2021, 6, 18, 13, 35, 51),
#  datetime.datetime(2021, 6, 18, 13, 35, 51)]

# %%
df['video_upload_time'] = plusthour
df.head()
# Out:
#    Unnamed: 0  Unnamed: 0.1  \
# 0           0             0
# 1           1             1
# 2           2             2
# 3           3             3
# 4           4             4
#
#                                               gen_id          username  \
# 0  7fadff0cb1c60a16b262bf21b6b7e8bbcdfb73cb1c0706...              bart
# 1  0b4f25bab3fa41470e586b2e3d017fe208ca29d5fce609...               Jet
# 2  3e16f39da717b9bbc8acb40d28f93356986157a9b35569...    Petruss.Aureus
# 3  2040b1137f54076443f06629e9d5e4ba2ad5dde012bb4c...             Elise
# 4  47a3c8ea3f22e7927edf0596e95f32f759e6c31951ee00...  Antonio Collenzo
#
#                                                 body  points children parents  \
# 0  WE ZIJN ER BIJNA, WE ZIJN ER BIJNA, MAAR NOG N...       0      NaN     NaN
# 1  Over medisch manipulatie gesproken , deze kan ...       0      NaN     NaN
# 2  Ohh ja Robert, tijd, geschiedenis, hoort tot e...       0      NaN     NaN
# ...

# %%
df.to_csv('jensen_comments')

# %%
df = df.drop(df['Unnamed: 0'])

# %%
df.head()
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, Unnamed: 0.1, gen_id, username, body, points, children, parents, date, date_retrieved, video_name, video_number, video_upload_time]
# Index: []
